# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.tree import DecisionClassifier
#       2 from sklearn.preprocessing import LabelEncoder
#
# ImportError: cannot import name 'DecisionClassifier' from 'sklearn.tree' (c:\Users\tejas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\tree\__init__.py)

# %%
income = ['High','Low','Medium','Low','Medium','High']
job_type = ['Permanent','Temporary','Permanent','Temporary','Permanent','Permanent']
existing_login = ['']
