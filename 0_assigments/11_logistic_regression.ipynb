# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = {
    "WorkHours" : [160,170,180,190,200,210,220],
    "Years" : [1,2,2,3,4,5,6],
    "Left" : [1,1,1,0,0,0,0]
}
df = pd.DataFrame(data)

# %%
x = df[["WorkHours","Years"]]
y = df["Left"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state =40)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)

y_predict = model.predict(x_test)

# %%
new_employee = [[175, 2]]
pred_class = model.predict(new_employee)[0]
pred_prob = model.predict_proba(new_employee)[0]
print(f"Predicted class: {pred_class}")
print(f"Prediction probabilities: [stay: {pred_prob[0]:.4f}, leave: {pred_prob[1]:.4f}]")
# Out:
# Predicted class: 1
# Prediction probabilities: [stay: 0.0036, leave: 0.9964]
# c:\Users\tejas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\tejas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
